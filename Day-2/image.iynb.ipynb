# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("thor.jpg")

# %%
arr = np.array(pil)

# %%
 arr.shape # 246 rows ,220 colums and depth of 3 .we got the pixls, 3 means the number of layers
# Out:
# (246, 220, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x1F07923EC08>

# %%
cut = arr[:5, :5]

# %%
plt.imshow(cut) # these are the 5 by 5 pixels

# %%
plt.imshow(arr)

# %%
work = arr.copy()

# %%
work[:, :, [1,2]]
# Out:
# array([[[ 68,  60],
#         [ 68,  60],
#         [ 69,  61],
#         ...,
#         [ 86,  70],
#         [ 84,  68],
#         [ 81,  67]],
#
#        [[ 67,  59],
#         [ 68,  60],
#         [ 68,  60],
#         ...,
#         [ 88,  72],
#         [ 86,  70],
#         [ 84,  70]],
#
#        [[ 67,  59],
#         [ 67,  59],
#         [ 68,  60],
#         ...,
#         [ 89,  73],
#         [ 88,  72],
#         [ 86,  72]],
#
#        ...,
#
#        [[141, 117],
#         [146, 122],
#         [138, 112],
#         ...,
#         [ 10,  11],
#         [ 10,  11],
#         [  9,  10]],
#
#        [[131, 110],
#         [139, 117],
#         [119,  95],
#         ...,
#         [ 11,  12],
#         [ 10,  11],
#         [  9,  10]],
#
#        [[109,  91],
#         [125, 107],
#         [107,  85],
#         ...,
#         [ 11,  12],
#         [ 10,  11],
#         [  9,  10]]], dtype=uint8)

# %%
work[:, :, [1,2]].shape
# Out:
# (246, 220, 2)

# %%
work[:, :, [1,2]] = 0

# %%
plt.imshow(work)

# %%
work[:, :, [1,2]] = 255 3 now redishness increase whitness

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray, cmap="gray") # cmap is colourmap

# %%
# converting bak into current image

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-aa6f8708ba06> in <module>
# ----> 1 plt.imshow(grey, cmap="grey")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...
